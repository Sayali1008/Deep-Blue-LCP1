# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Deep Blue/Data/Wardwise Data/Final.csv', header = None)
df.head()
# Out:
#    0     1            2            3  ...         6        7         8          9
# 0  1  2014  37940409.89  2655046.996  ...  349587.0  87596.0  261991.0  24.319149
# 1  2  2014  37811107.44  2647108.576  ...  349916.0  87678.0  262238.0  24.319149
# 2  3  2014  38005061.11  2655046.996  ...  350245.0  87760.0  262484.0  24.319149
# 3  4  2014  38134363.56  2662985.417  ...  350574.0  87843.0  262731.0  24.319149
# 4  5  2014  38392968.45  2678862.257  ...  350903.0  87925.0  262977.0  24.319149
#
# [5 rows x 10 columns]

# %%
cols = ['Month', 'Year','Demand','Consumption','Connections','Ward','Total Population','Slum Population', 'Non-Slum Population','Rainfall']
df.columns = cols

# %%
df.head()
# Out:
#    Month  Year       Demand  ...  Slum Population  Non-Slum Population   Rainfall
# 0      1  2014  37940409.89  ...          87596.0             261991.0  24.319149
# 1      2  2014  37811107.44  ...          87678.0             262238.0  24.319149
# 2      3  2014  38005061.11  ...          87760.0             262484.0  24.319149
# 3      4  2014  38134363.56  ...          87843.0             262731.0  24.319149
# 4      5  2014  38392968.45  ...          87925.0             262977.0  24.319149
#
# [5 rows x 10 columns]

# %%
df.hist(figsize=(10,10), bins=10)
plt.show()

# %%
g = sns.pairplot(df,
              y_vars=['Consumption'],
              x_vars=['Total Population'],
             kind='reg', plot_kws={'line_kws': {'color' : 'red'}, 'scatter_kws': {'alpha': 0.3}})
g.fig.set_size_inches(15,9)
g.fig.legend(handles=handles, labels=labels, loc='upper center')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
g = sns.pairplot(df,
              y_vars=['Consumption'],
              x_vars=['Connections'],
             kind='reg', plot_kws={'line_kws': {'color' : 'red'}, 'scatter_kws': {'alpha': 0.3}})
g.fig.set_size_inches(15,9)

plt.show()

# %%
g = sns.pairplot(df,
              y_vars=['Consumption'],
              x_vars=['Slum Population'],
             kind='reg', plot_kws={'line_kws': {'color' : 'red'}, 'scatter_kws': {'alpha': 0.3}})
g.fig.set_size_inches(15,9)

plt.show()

# %%
g = sns.pairplot(df,
              y_vars=['Consumption'],
              x_vars=['Non-Slum Population'],
             kind='reg', plot_kws={'line_kws': {'color' : 'red'}, 'scatter_kws': {'alpha': 0.3}})
g.fig.set_size_inches(15,9)

plt.show()

# %%
np.any(np.isnan(mat))

# %%
df
# Out:
#       Month  Year       Demand  ...  Slum Population  Non-Slum Population   Rainfall
# 0         1  2014  37940409.89  ...          87596.0             261991.0  24.319149
# 1         2  2014  37811107.44  ...          87678.0             262238.0  24.319149
# 2         3  2014  38005061.11  ...          87760.0             262484.0  24.319149
# 3         4  2014  38134363.56  ...          87843.0             262731.0  24.319149
# 4         5  2014  38392968.45  ...          87925.0             262977.0  24.319149
# ...     ...   ...          ...  ...              ...                  ...        ...
# 1615      8  2018  81230016.25  ...          24020.0             175428.0  16.577670
# 1616      9  2018  80748653.52  ...          24043.0             175592.0  16.577670
# 1617     10  2018  80267290.79  ...          24065.0             175756.0  16.577670
# 1618     11  2018  80026609.42  ...          24088.0             175920.0  16.577670
# ...

# %%
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df = df.dropna()
X = df['Total Population'];
Y = df['Consumption'];

X=np.asarray(X)
Y=np.asarray(Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
Y_train = Y_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
X_train = X_train.reshape(-1,1)
reg = LinearRegression()
reg.fit(X_train, Y_train)
print(reg.intercept_)
print(reg.coef_)
# Out:
# [336666.96238761]
# [[4.23192372]]

# %%
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df = df.dropna()
X = df['Connections'];
Y = df['Consumption'];

X=np.asarray(X)
Y=np.asarray(Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
Y_train = Y_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
X_train = X_train.reshape(-1,1)
reg = LinearRegression()
reg.fit(X_train, Y_train)
print(reg.intercept_)
print(reg.coef_)
# Out:
# [968897.08817436]
# [[116.80254054]]

# %%
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df = df.dropna()
X = df['Slum Population'];
Y = df['Consumption'];

X=np.asarray(X)
Y=np.asarray(Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
Y_train = Y_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
X_train = X_train.reshape(-1,1)
reg = LinearRegression()
reg.fit(X_train, Y_train)
print(reg.intercept_)
print(reg.coef_)
# Out:
# [1679676.38232069]
# [[3.40419859]]

# %%
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df = df.dropna()
X = df['Non-Slum Population'];
Y = df['Consumption'];

X=np.asarray(X)
Y=np.asarray(Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
Y_train = Y_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
X_train = X_train.reshape(-1,1)
reg = LinearRegression()
reg.fit(X_train, Y_train)
print(reg.intercept_)
print(reg.coef_)
# Out:
# [1087566.66179588]
# [[6.08674052]]

# %%
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df = df.dropna()
X = df['Ward'];
Y = df['Consumption'];

X=np.asarray(X)
Y=np.asarray(Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
Y_train = Y_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
X_train = X_train.reshape(-1,1)
reg = LinearRegression()
reg.fit(X_train, Y_train)
print(reg.intercept_)
print(reg.coef_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e4c510b28f25> in <module>()
#      15 X_train = X_train.reshape(-1,1)
#      16 reg = LinearRegression()
# ---> 17 reg.fit(X_train, Y_train)
#      18 print(reg.intercept_)
#      19 print(reg.coef_)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# ...
